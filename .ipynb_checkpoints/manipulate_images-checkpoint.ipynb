# %% [markdown]
# # Radmc3D Image Manipulation

# %% [markdown]
# ## 01 - Fits Image

# %%
from matplotlib import pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS

# %%
filename = 'HD163296_wav1324.fits'
hdu = fits.open(filename)[0]

wcs = WCS(hdu.header)
print(wcs)

#fig = plt.figure()
#fig.add_subplot(111, projection=wcs)
#plt.xlabel('RA')
#plt.ylabel('Dec')
# Out:
# WCS Keywords
#
# Number of WCS axes: 3
# CTYPE : 'RA---SIN'  'DEC--SIN'  'FREQ'
# CRVAL : 269.0887009119171  -21.95607565091166  226429348942.5982
# CRPIX : 250.5  250.5  1.0
# PC1_1 PC1_2 PC1_3  : 1.0  0.0  0.0
# PC2_1 PC2_2 PC2_3  : 0.0  1.0  0.0
# PC3_1 PC3_2 PC3_3  : 0.0  0.0  1.0
# CDELT : -2.2768670309653e-06  2.27686703096539e-06  2000000000.0
# NAXIS : 500  500  1

# %%
from matplotlib import pyplot as plt
from astropy.io import fits
from astropy.wcs import WCS
from astropy.utils.data import get_pkg_data_filename

filename = get_pkg_data_filename('tutorials/FITS-images/HorseHead.fits')
hdu = fits.open(filename)[0]
wcs = WCS(hdu.header)
print(wcs)

fig = plt.figure()
fig.add_subplot(111, projection=wcs)
plt.imshow(hdu.data, origin='lower', cmap=plt.cm.viridis)
plt.xlabel('RA')
plt.ylabel('Dec')
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 85.59941666666666  -4.946638888888889
# CRPIX : -716.333144294269  -8444.64946698226
# PC1_1 PC1_2  : 0.015029018460682027  -9.63735777657198e-06
# PC2_1 PC2_2  : 1.0548917307845708e-05  0.015000473845055023
# CDELT : -0.018654788242111486  0.018654788242111486
# NAXIS : 891  893
